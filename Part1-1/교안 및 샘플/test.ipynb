# %%
print("who sdkfksdfjiefksjdf    sdfsd  sdf  am i")
# Out:
# who am i

# %%
print("who are you dkkiiejflkj a;sdi  wefkljoi asdf  ijwefoij ; ")
# Out:
# who are you dkkiiejflkj a;sdi  wefkljoi asdf  ijwefoij ;

# %%
# ipykernel 설치
