# %%
# Prompt

# 1. Prompt Template
# 2. Variable

# 재사용 + 효율성
# 잘 설계된 prompt는 정확한 응답을 유도

# %%
# conda install langchain
# python -m pip install python-dotenv
# python -m pip install langchain-google-genai

# %%
import os
from dotenv import load_dotenv

# 소스 코드에 민감한 정보를 노출하지 않는 방법
# .env 파일에 GOOGLE_API_KEY="YOUR_API_KEY"
# 변수 참조는 os.environ['GOOGLE_API_KEY']
# load_dotenv()의 리턴은 True/False
# .env 파일 찾기 성공, 환경 변수 설정 완료 → True
# .env 파일 찾기 실패 → False
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# LLM 객체 생성
llm = ChatGoogleGenerativeAI(model="gemini-2.0-flash")

# 일반 문자열 입력
response = llm.invoke("LangChain은 무엇인가요?")
print(response)
# Out:
# content='LangChain은 **대규모 언어 모델(LLM, Large Language Model)을 활용하여 다양한 애플리케이션을 구축할 수 있도록 도와주는 프레임워크**입니다. LLM의 잠재력을 최대한 활용하기 위한 도구 상자라고 생각하시면 됩니다.\n\n**핵심 기능 및 특징:**\n\n*   **LLM 연쇄 (Chains):** LLM을 단순히 사용하는 것 이상으로, 여러 LLM 호출을 연결하여 복잡한 작업을 수행할 수 있도록 합니다. 예를 들어, 질문에 답하기 위해 먼저 문서를 검색하고, 검색된 내용을 바탕으로 LLM에 질문하여 답변을 생성하는 과정을 자동화할 수 있습니다.\n*   **데이터 연결 (Data Connection):** 다양한 데이터 소스 (웹 페이지, 문서, 데이터베이스 등)에서 데이터를 가져와 LLM이 활용할 수 있도록 연결해줍니다. 이를 통해 LLM은 외부 지식을 활용하여 더욱 풍부하고 정확한 답변을 제공할 수 있습니다.\n*   **에이전트 (Agents):** LLM이 외부 도구를 사용하여 의사 결정을 내리고 작업을 수행할 수 있도록 합니다. 예를 들어, LLM 에이전트는 날씨 정보를 검색하거나, 이메일을 보내거나, 코드를 실행하는 등의 작업을 수행할 수 있습니다.\n*   **메모리 (Memory):** LLM은 기본적으로 이전 대화 내용을 기억하지 못합니다. LangChain은 메모리 기능을 제공하여 LLM이 이전 상호 작용을 기억하고, 이를 바탕으로 더욱 맥락에 맞는 답변을 제공할 수 있도록 합니다.\n\n**LangChain의 장점:**\n\n*   **개발 속도 향상:** LLM 애플리케이션 개발에 필요한 다양한 구성 요소를 미리 제공하여 개발 시간을 단축시켜줍니다.\n*   **유연성 및 확장성:** 다양한 LLM, 데이터 소스, 도구와 통합될 수 있도록 설계되어 사용자의 요구에 맞게 맞춤화할 수 있습니다.\n*   **활발한 커뮤니티:** 활발한 오픈 소스 커뮤니티를 통해 다양한 정보와 지원을 얻을 수 있습니다.\n\n**LangChain의 활용 분야:**\n\n*   **챗봇:** 고객 지원, 질문 응답, 개인 비서 등 다양한 챗봇 개발에 활용됩니다.\n*   **문서 요약:** 긴 문서를 자동으로 요약하여 핵심 내용을 빠르게 파악할 수 있도록 돕습니다.\n*   **코드 생성:** 자연어 설명을 바탕으로 코드를 자동으로 생성합니다.\n*   **데이터 분석:** 자연어 질문을 통해 데이터 분석을 수행하고 결과를 시각화합니다.\n*   **자동화된 워크플로우:** LLM을 활용하여 복잡한 워크플로우를 자동화합니다.\n\n**요약:**\n\nLangChain은 LLM을 활용하여 강력하고 다양한 애플리케이션을 구축할 수 있도록 지원하는 강력한 프레임워크입니다. LLM을 활용한 애플리케이션 개발에 관심이 있다면 LangChain을 학습하고 활용하는 것을 고려해볼 수 있습니다.\n\n더 궁금한 점이 있으시면 언제든지 질문해주세요.' additional_kwargs={} response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []} id='run--4db32c95-dd71-4d3d-b38f-07ac3e558bd9-0' usage_metadata={'input_tokens': 9, 'output_tokens': 817, 'total_tokens': 826, 'input_token_details': {'cache_read': 0}}

# %%
# LangChain에서 실행할 수 있는 모든 대상은 Runnable 객체
# Runnable 객체는 Runnable 인터페이스를 구현한 클래스의 인스턴스

# LangChain에서 invoke, stream, batch는 모두 Runnable 객체를 실행하는 메서드

# invoke는 하나의 입력에 대해 모델을 한 번 호출하여 최종 결과물을 즉시 반환하는 동기(synchronous) 방식의 메서드
# batch는 여러 개의 입력을 리스트 형태로 받아 한 번의 호출로 병렬 처리하고, 각각의 결과물을 리스트로 반환하는 메서드
# stream은 모델의 응답을 실시간으로, 토큰(단어) 단위로 스트리밍하여 반환하는 메서드 (기다리지 않음)

# %%
# 파이썬 format
# 문자열의 중괄호 {}를 값으로 채워 넣음

template = "안녕하세요, {name}님. 오늘은 {topic}에 대해 이야기해볼까요?"
filled = template.format(name="희망", topic="LangChain")
print(filled)
# Out:
# 안녕하세요, 희망님. 오늘은 LangChain에 대해 이야기해볼까요?

# %%
from langchain_core.prompts import PromptTemplate

# 템플릿 정의
template = PromptTemplate.from_template("안녕하세요, {name}님!")
# print(template)

# .invoke()에 전달하는 값은 딕셔너리
# .invoke()에 딕셔너리를 사용하는 이유는 템플릿 안의 변수 이름과 값을 연결하기 위함
# 템플릿에 정의된 모든 변수 값이 할당되어야 함

# filled = template.invoke({"name": "희망"})
filled = template.invoke("희망")

# LangChain은 템플릿에 필요한 변수가 하나뿐일 때, 단일 문자열이나 숫자를 넘기면 자동으로 그 값을 첫 번째 변수에 매핑
# 템플릿 변수 개수가 1이면 단일 값 또는 딕셔너리
print(filled)
# Out:
# text='안녕하세요, 희망님!'

# %%
from langchain_core.prompts import PromptTemplate

# 템플릿 정의 (두 개의 변수: name, day)
template = PromptTemplate.from_template("안녕하세요, {name}님! 오늘은 {day}입니다.")

# .invoke()에 전달하는 값이 딕셔너리 형태로 두 변수 모두 포함
filled = template.invoke({"name": "희망", "day": "수요일"})

print(filled)
# Out:
# text='안녕하세요, 희망님! 오늘은 수요일입니다.'

# %%
#####################################################################################################

# %%
# 가장 단순한 프롬프트 예제

# langchain 라이브러리에서 필요한 클래스 임포트
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain

# 1. 모델 생성
# ChatGoogleGenerativeAI는 LangChain 클래스
# Google의 생성형 AI 모델을 사용하기 위한 클래스
# ChatGoogleGenerativeAI는 대화 중심, Gemini 모델 지원
llm = ChatGoogleGenerativeAI(model="gemini-2.0-flash")

# 2. PromptTemplate 생성
# {topic} 변수를 포함한 프롬프트 템플릿을 정의
template = "다음 주제에 대해 간결하게 설명해 줘: {topic}"
prompt = PromptTemplate.from_template(template)

# 3. Chain 생성
# 프롬프트와 언어 모델을 연결하여 체인을 생성
# 체인의 요소는 Runnable 객체로서 invoke(), batch(), stream()으로 실행
# Runnable 객체를 체인으로 묶으면 체인 그 자체도 Runnable 객체

chain = prompt | llm

# 4. 체인 실행 및 결과 출력
topic = "LangChain의 프롬프트"

print('---', prompt.format(topic=topic)) # {topic}의 값이 채워진 prompt의 문자열을 확인
response = chain.invoke(topic)

print(response)
# Out:
# --- 다음 주제에 대해 간결하게 설명해 줘: LangChain의 프롬프트
# content='## LangChain 프롬프트: LLM과의 효과적인 대화를 위한 설계도\n\nLangChain에서 프롬프트는 **LLM(Large Language Model)에게 전달되는 입력 텍스트**를 의미합니다. 단순히 질문이나 명령어를 넘어서, LLM이 원하는 방식으로 응답하도록 **구조화된 텍스트**를 설계하는 것이 중요합니다.\n\n**핵심:**\n\n*   **LLM 행동 제어:** 프롬프트는 LLM이 어떤 방식으로 답변해야 하는지 (예: 요약, 번역, 코드 생성 등) 지시합니다.\n*   **맥락 제공:** 프롬프트는 LLM에게 필요한 정보를 제공하여 답변의 정확성과 관련성을 높입니다.\n*   **템플릿 활용:** LangChain은 프롬프트 템플릿을 제공하여 재사용 가능하고 동적인 프롬프트를 쉽게 만들 수 있도록 돕습니다.\n*   **다양한 유형:** 단순 텍스트, 지시 사항, 예시, 질문 등 다양한 형태로 구성될 수 있습니다.\n\n**LangChain 프롬프트의 중요성:**\n\n잘 설계된 프롬프트는 LLM의 성능을 극대화하고 원하는 결과를 얻는 데 필수적입니다. LangChain은 프롬프트 엔지니어링을 위한 다양한 도구와 기능을 제공하여 개발자가 더욱 효과적인 LLM 애플리케이션을 구축할 수 있도록 지원합니다.' additional_kwargs={} response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []} id='run--bceed504-1a14-43e3-96ca-f7d6e8bf9833-0' usage_metadata={'input_tokens': 21, 'output_tokens': 363, 'total_tokens': 384, 'input_token_details': {'cache_read': 0}}

# %%
# 두 개의 변수 값을 사용하는 템플릿

from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.prompts import PromptTemplate

# 1. 모델 객체 생성
llm = ChatGoogleGenerativeAI(model="gemini-2.0-flash")

# 2. PromptTemplate 객체 생성
template = "{language}로 다음 주제를 간결하게 설명해 줘: {topic}"
prompt = PromptTemplate.from_template(template)

# 3. PromptTemplate과 LLM을 바로 파이프(|)로 연결하여 체인 생성
chain = prompt | llm

# 4. 체인 실행 시 변수 딕셔너리 전달
response = chain.invoke({
    "language": "한국어",
    "topic": "LangChain"
})

# 결과 출력
print(response.content)
# Out:
# ## LangChain: 거대 언어 모델(LLM) 활용을 위한 도구 상자
#
# LangChain은 **LLM(Large Language Model, 거대 언어 모델)**을 사용하여 다양한 애플리케이션을 구축하는 데 필요한 도구와 프레임워크를 제공하는 **오픈 소스 라이브러리**입니다.
#
# **쉽게 말해,** LLM을 더 똑똑하게 만들고, 다양한 데이터와 연결하고, 복잡한 작업을 수행하도록 돕는 도구 모음입니다.
#
# **핵심 기능:**
#
# *   **모델 연결:** 다양한 LLM(GPT, Bard 등)을 쉽게 연결하고 관리
# *   **데이터 연결:** 외부 데이터 소스(문서, 웹사이트, 데이터베이스 등)와 LLM 연결
# *   **체인(Chains):** 여러 LLM 호출을 연결하여 복잡한 작업 수행 (예: 질문 응답, 문서 요약)
# *   **에이전트(Agents):** LLM이 스스로 도구를 선택하고 사용하여 목표를 달성 (예: 웹 검색, 계산)
#
# **LangChain의 목표:**
#
# LLM을 활용하여 더욱 강력하고 유용한 애플리케이션을 더 쉽게 만들 수 있도록 돕는 것입니다.
#
# **예시:**
#
# *   문서 내용을 기반으로 질문에 답변하는 챗봇
# *   웹 검색을 통해 최신 정보를 얻어 답변하는 에이전트
# *   데이터베이스를 분석하여 보고서를 생성하는 도구

# %%
# 일반 함수를 Runnable 객체로 변환해서 입력 내용 확인하기

# langchain 라이브러리에서 필요한 클래스 임포트
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain
# RunnableLambda 클래스 임포트
from langchain_core.runnables import RunnableLambda

# 1. 모델 생성
# ChatGoogleGenerativeAI는 LangChain 클래스
# Google의 생성형 AI 모델을 사용하기 위한 클래스
# ChatGoogleGenerativeAI는 대화 중심, Gemini 모델 지원
llm = ChatGoogleGenerativeAI(model="gemini-2.0-flash")

# 2. PromptTemplate 생성
# {topic} 변수를 포함한 프롬프트 템플릿을 정의
# {topic} 변수의 값은 체인을 호출할 때 전달
template = "다음 주제에 대해 간결하게 설명해 줘: {topic}"
prompt = PromptTemplate.from_template(template)

# 3. Chain 생성
# 프롬프트와 언어 모델을 연결하여 체인을 생성
# 체인의 요소는 Runnable 객체로서 invoke(), batch(), stream()으로 실행
# Runnable 객체를 체인으로 묶으면 체인 그 자체도 Runnable 객체


def log_and_pass(x):
    print(f"\n[로그] 현재 단계 입력값: {x}\n")
    return x
# RunnableLambda은 일반 함수를 Runnable 객체로 변환
# 즉, 일반 함수를 체인에서 실행할 수 있게 하는 역할
# Runnable 객체로 변환된 함수는 이전 단계의 출력을 입력으로 받음
logger = RunnableLambda(log_and_pass)


# 체인에 로거를 추가
# prompt의 입력은 'topic' 변수의 값
# llm의 입력은 prompt의 출력
chain = logger | prompt | logger | llm

# #################### 추가 코드 끝 ####################

# 4. 체인 실행 및 결과 출력
topic = "LangChain의 프롬프트"
response = chain.invoke(topic)

print(response)
# Out:
# [로그] 현재 단계 입력값: LangChain의 프롬프트
#
#
# [로그] 현재 단계 입력값: text='다음 주제에 대해 간결하게 설명해 줘: LangChain의 프롬프트'
#
# content='## LangChain의 프롬프트: 모델에게 효과적인 지시를 내리는 핵심 요소\n\nLangChain에서 프롬프트는 **언어 모델(LLM)에게 특정 작업을 수행하도록 지시하는 입력 텍스트**입니다. 단순히 질문을 던지는 것 이상으로, 모델의 행동을 제어하고 원하는 결과를 얻기 위한 핵심적인 도구입니다.\n\n**핵심 역할:**\n\n*   **작업 정의:** 모델이 수행해야 할 작업을 명확하게 정의합니다 (예: 번역, 요약, 질문 답변 등).\n*   **맥락 제공:** 필요한 배경 정보, 관련 데이터, 예시 등을 제공하여 모델이 정확하게 이해하도록 돕습니다.\n*   **출력 형식 지정:** 원하는 출력 형식 (예: JSON, 코드, 목록 등)을 지정하여 모델이 일관된 결과를 생성하도록 합니다.\n*   **모델 제어:** 온도, 최대 토큰 수 등 모델 파라미터를 조절하여 창의성, 정확성, 응답 길이를 제어합니다.\n\n**LangChain의 프롬프트 구성 요소:**\n\n*   **프롬프트 템플릿:** 동적으로 프롬프트를 생성하기 위한 템플릿. 사용자 입력, 데이터 등을 변수로 활용하여 유연하게 프롬프트를 구성합니다.\n*   **출력 파서:** 모델의 출력을 원하는 형식으로 변환하는 도구. JSON, 객체 등으로 파싱하여 후속 작업에 활용합니다.\n\n**결론:**\n\nLangChain에서 프롬프트는 단순한 텍스트 입력을 넘어, 언어 모델을 효과적으로 활용하기 위한 **설계 도구**입니다. 프롬프트 엔지니어링을 통해 모델의 성능을 극대화하고, 다양한 애플리케이션을 구축할 수 있습니다.' additional_kwargs={} response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []} id='run--ef9e5081-f80b-4054-8f50-1927a1ef3443-0' usage_metadata={'input_tokens': 21, 'output_tokens': 450, 'total_tokens': 471, 'input_token_details': {'cache_read': 0}}

# %%
# 체인의 어떤 단계에서 출력이 둘 이상인 경우 딕셔너리 형태로 만들어야 함

# 1. RunnableParallel
# 2. RunnablePassthrough.assign()
# 3. JsonOutputParser

# %%
# RunnableParallel

from langchain_core.prompts import PromptTemplate
from langchain_core.runnables import RunnableParallel
from langchain_google_genai import ChatGoogleGenerativeAI

# 1. 모델 생성
llm = ChatGoogleGenerativeAI(model="gemini-2.0-flash")

# 2. PromptTemplate 생성
name_prompt = PromptTemplate.from_template(
    "다음 제품 타입에 어울리는 창의적인 이름을 하나만 만들어 주세요:\n\n제품 타입: {product_type}"
)
slogan_prompt = PromptTemplate.from_template(
    "다음 키워드를 사용해 기억에 남는 슬로건을 하나만 만들어 주세요:\n\n키워드: {keyword}"
)

# 3. Chain 생성
name_chain = name_prompt | llm
slogan_chain = slogan_prompt | llm

# 3. RunnableParallel로 두 체인을 병렬 실행
combined_chain = RunnableParallel(
    name=name_chain, # name_prompt | llm
    slogan=slogan_chain # slogan_prompt | llm
)
# combined_chain을 실행하면 다음과 같은 딕셔너리가 리턴

# {
#   "name": "name_chain의 실행 결과",
#   "slogan": "slogan_chain의 실행 결과"
# }

# 4. 최종 문장을 생성하는 프롬프트와 체인
final_prompt = PromptTemplate.from_template(
    "'{name}'이라는 제품을 위한 슬로건은 '{slogan}'입니다."
)

# 5. 모든 체인 결합
final_chain = combined_chain | final_prompt | llm

result = final_chain.invoke({"product_type": "스마트 커피 머신", "keyword": "편리함"})
# {"product_type": "스마트 커피 머신", "keyword": "편리함"} >>> 'name': name_chain(name_prompt | llm) 
# {"product_type": "스마트 커피 머신", "keyword": "편리함"} >>> 'slogan': slogan_chain(slogan_prompt | llm)
print(result.content)
# Out:
# c:\Users\bayesian\miniconda3\envs\py310_64\lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(
# 네, 알겠습니다. "카페오토 (CafeAuto)" 제품의 슬로건은 "**편리함, 일상을 디자인하다.**"입니다.

# %%
# RunnablePassthrough.assign()
# 출력에 키 값을 부여


from langchain_core.prompts import PromptTemplate
from langchain_core.runnables import RunnablePassthrough
from langchain_google_genai import ChatGoogleGenerativeAI

# 1. 모델 생성
llm = ChatGoogleGenerativeAI(model="gemini-2.0-flash")

# 2. '재료'를 생성하는 체인
ingredients_chain = (
    PromptTemplate.from_template("{dish}에 들어가는 재료 3가지를 알려줘.")
    | llm
)

# 3. 최종 프롬프트는 'dish'와 'ingredients'라는 두 개의 변수를 필요
final_prompt = PromptTemplate.from_template(
    "'{dish}'을 만드는 주요 재료는 다음과 같습니다:\n{ingredients}"
)

# 4. RunnablePassthrough.assign()을 사용하여 체인 구성
chain = (
    RunnablePassthrough.assign(
        ingredients=ingredients_chain # PromptTemplate.from_template("{dish}에 들어가는 재료 3가지를 알려줘.") | llm
        # ingredients_chain의 결과에 키 'ingredients'를 부여
        # 체인의 다음 단계인 final_prompt에서 {ingredients}을 사용하기 때문에 거기에 맞춘 것
    )
    | final_prompt
    | llm
)

# 5. 체인 실행
# 초기 입력으로 {"dish": "김치찌개"}를 전달, 이 값은 체인의 모든 단계에 전달
result = chain.invoke({"dish": "김치찌개"})

print(result.content)
# Out:
# 제공된 텍스트에 따르면 김치찌개를 만드는 주요 재료 3가지는 다음과 같습니다:
#
# 1.  **김치**: 잘 익은 김치가 김치찌개의 맛을 좌우합니다.
# 2.  **돼지고기 (또는 참치, 햄 등)**: 돼지고기는 김치찌개에 깊은 맛을 더해줍니다.
# 3.  **두부**: 두부는 김치찌개의 단백질을 보충해주고, 부드러운 식감을 더해줍니다.

# %%
# PromptTemplate와 PromptTemplate.from_template

from langchain_core.prompts import PromptTemplate

# 1. PromptTemplate
# input_variables를 명시적으로 할당해서 검증
# 검증이란
# 템플릿에 {input}이 있는데 input_variables에 "input"이 있는지 없는지
# input_variables에 "input"이 있는데 템플릿에 {input}이 있는지 없는지

manual_prompt = PromptTemplate(
    input_variables=["animal", "food"],
    template="내가 좋아하는 동물은 {animal}이고, 좋아하는 음식은 {food}야.",
)

# 2. PromptTemplate.from_template
# template 문자열만 제공, 변수를 자동으로 파싱
auto_prompt = PromptTemplate.from_template(
    "내가 좋아하는 동물은 {animal}이고, 좋아하는 음식은 {food}야."
)

# 두 템플릿은 동일
print(manual_prompt.format(animal="강아지", food="사료"))
print(auto_prompt.format(animal="고양이", food="생선"))
# Out:
# 내가 좋아하는 동물은 강아지이고, 좋아하는 음식은 사료야.
# 내가 좋아하는 동물은 고양이이고, 좋아하는 음식은 생선야.
